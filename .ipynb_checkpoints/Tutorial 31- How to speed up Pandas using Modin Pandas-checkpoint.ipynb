# %% [markdown]
# ## Using Pandas

# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv('./data/modin_test.csv')
df.head()
# Out:
# CPU times: total: 8.25 s
# Wall time: 9.67 s
#                       file  round   tick   seconds          att_team  \
# 0  esea_match_13770997.dem      1  14372  111.8476             World
# 1  esea_match_13770997.dem      1  15972  124.3761      Animal Style
# 2  esea_match_13770997.dem      1  16058  125.0495      Animal Style
# 3  esea_match_13770997.dem      1  16066  125.1121  Hentai Hooligans
# 4  esea_match_13770997.dem      1  16108  125.4410      Animal Style
#
#            vic_team          att_side          vic_side  hp_dmg  arm_dmg  ...  \
# 0      Animal Style               NaN  CounterTerrorist       1        0  ...
# 1  Hentai Hooligans  CounterTerrorist         Terrorist      18        9  ...
# 2  Hentai Hooligans  CounterTerrorist         Terrorist     100        0  ...
# 3      Animal Style         Terrorist  CounterTerrorist      12        7  ...
# 4  Hentai Hooligans  CounterTerrorist         Terrorist      15        7  ...
#
# ...

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: total: 1.11 s
# Wall time: 1.29 s
#                          file    round     tick  seconds  vic_team  att_side  \
# att_team
# --to be determined--      669      669      669      669       669       669
# AGO Esports               718      718      718      718       718       718
# ALTERNATE aTTaX           577      577      577      577       577       577
# Animal Style              362      362      362      362       362       362
# EURONICS Gaming           774      774      774      774       774       774
# Endpoint                  708      708      708      708       708       708
# Hentai Hooligans          389      389      389      389       389       389
# Izako Boars              1430     1430     1430     1430      1430      1430
# ONCA Gaming               262      262      262      262       262       262
# PACT                      741      741      741      741       741       741
# ...

# %%
import modin.pandas as pd

# %%
# %%time
df = pd.read_csv('./data/modin_test.csv')
df.head()
# Out:
# CPU times: total: 625 ms
# Wall time: 4.66 s
#                       file  round   tick   seconds          att_team  \
# 0  esea_match_13770997.dem      1  14372  111.8476             World
# 1  esea_match_13770997.dem      1  15972  124.3761      Animal Style
# 2  esea_match_13770997.dem      1  16058  125.0495      Animal Style
# 3  esea_match_13770997.dem      1  16066  125.1121  Hentai Hooligans
# 4  esea_match_13770997.dem      1  16108  125.4410      Animal Style
#
#            vic_team          att_side          vic_side  hp_dmg  arm_dmg  ...  \
# 0      Animal Style               NaN  CounterTerrorist       1        0  ...
# 1  Hentai Hooligans  CounterTerrorist         Terrorist      18        9  ...
# 2  Hentai Hooligans  CounterTerrorist         Terrorist     100        0  ...
# 3      Animal Style         Terrorist  CounterTerrorist      12        7  ...
# 4  Hentai Hooligans  CounterTerrorist         Terrorist      15        7  ...
#
# ...

# %%
# %%time
df.groupby('att_team').count()
# Out:
# CPU times: total: 46.9 ms
# Wall time: 54.9 ms
#                          file    round     tick  seconds  vic_team  att_side  \
# att_team
# --to be determined--      669      669      669      669       669       669
# AGO Esports               718      718      718      718       718       718
# ALTERNATE aTTaX           577      577      577      577       577       577
# Animal Style              362      362      362      362       362       362
# EURONICS Gaming           774      774      774      774       774       774
# Endpoint                  708      708      708      708       708       708
# Hentai Hooligans          389      389      389      389       389       389
# Izako Boars              1430     1430     1430     1430      1430      1430
# ONCA Gaming               262      262      262      262       262       262
# PACT                      741      741      741      741       741       741
# ...
